# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')

train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 268.2308 - y1_output_loss: 126.5920 - y2_output_loss: 139.1587 - y1_output_root_mean_squared_error: 11.3054 - y2_output_root_mean_squared_error: 11.8498 - val_loss: 36.0281 - val_y1_output_loss: 13.9079 - val_y2_output_loss: 22.5623 - val_y1_output_root_mean_squared_error: 3.6797 - val_y2_output_root_mean_squared_error: 4.7422
# Epoch 2/500
# 614/614 [==============================] - 0s 160us/sample - loss: 30.6811 - y1_output_loss: 12.9935 - y2_output_loss: 18.3648 - y1_output_root_mean_squared_error: 3.5583 - y2_output_root_mean_squared_error: 4.2449 - val_loss: 116.1399 - val_y1_output_loss: 25.9717 - val_y2_output_loss: 88.6507 - val_y1_output_root_mean_squared_error: 5.1627 - val_y2_output_root_mean_squared_error: 9.4597
# Epoch 3/500
# 614/614 [==============================] - 0s 157us/sample - loss: 30.0522 - y1_output_loss: 11.1989 - y2_output_loss: 18.8277 - y1_output_root_mean_squared_error: 3.3577 - y2_output_root_mean_squared_error: 4.3334 - val_loss: 40.4701 - val_y1_output_loss: 8.9563 - val_y2_output_loss: 30.6437 - val_y1_output_root_mean_squared_error: 3.0410 - val_y2_output_root_mean_squared_error: 5.5877
# Epoch 4/500
# 614/614 [==============================] - 0s 155us/sample - loss: 24.8389 - y1_output_loss: 9.7831 - y2_output_loss: 15.1726 - y1_output_root_mean_squared_error: 3.1248 - y2_output_root_mean_squared_error: 3.8826 - val_loss: 40.5172 - val_y1_output_loss: 13.9521 - val_y2_output_loss: 27.7199 - val_y1_output_root_mean_squared_error: 3.6641 - val_y2_output_root_mean_squared_error: 5.2050
# Epoch 5/500
# 614/614 [==============================] - 0s 155us/sample - loss: 22.4851 - y1_output_loss: 9.3827 - y2_output_loss: 13.0027 - y1_output_root_mean_squared_error: 3.0622 - y2_output_root_mean_squared_error: 3.6205 - val_loss: 22.0487 - val_y1_output_loss: 8.9331 - val_y2_output_loss: 12.9524 - val_y1_output_root_mean_squared_error: 2.9775 - val_y2_output_root_mean_squared_error: 3.6308
# Epoch 6/500
# 614/614 [==============================] - 0s 155us/sample - loss: 24.2890 - y1_output_loss: 9.5046 - y2_output_loss: 14.7839 - y1_output_root_mean_squared_error: 3.0834 - y2_output_root_mean_squared_error: 3.8447 - val_loss: 24.0882 - val_y1_output_loss: 7.6381 - val_y2_output_loss: 16.3837 - val_y1_output_root_mean_squared_error: 2.7776 - val_y2_output_root_mean_squared_error: 4.0464
# Epoch 7/500
# 614/614 [==============================] - 0s 152us/sample - loss: 26.0624 - y1_output_loss: 9.8792 - y2_output_loss: 16.3127 - y1_output_root_mean_squared_error: 3.1355 - y2_output_root_mean_squared_error: 4.0288 - val_loss: 61.1850 - val_y1_output_loss: 16.7775 - val_y2_output_loss: 45.9160 - val_y1_output_root_mean_squared_error: 4.0178 - val_y2_output_root_mean_squared_error: 6.7114
# Epoch 8/500
# 614/614 [==============================] - 0s 149us/sample - loss: 22.3663 - y1_output_loss: 9.0634 - y2_output_loss: 13.1862 - y1_output_root_mean_squared_error: 3.0203 - y2_output_root_mean_squared_error: 3.6392 - val_loss: 33.8199 - val_y1_output_loss: 10.8328 - val_y2_output_loss: 23.7355 - val_y1_output_root_mean_squared_error: 3.2383 - val_y2_output_root_mean_squared_error: 4.8305
# Epoch 9/500
# 614/614 [==============================] - 0s 149us/sample - loss: 21.7109 - y1_output_loss: 8.6123 - y2_output_loss: 13.0064 - y1_output_root_mean_squared_error: 2.9391 - y2_output_root_mean_squared_error: 3.6156 - val_loss: 23.5815 - val_y1_output_loss: 9.3085 - val_y2_output_loss: 14.3903 - val_y1_output_root_mean_squared_error: 3.0288 - val_y2_output_root_mean_squared_error: 3.7958
# Epoch 10/500
# 614/614 [==============================] - 0s 153us/sample - loss: 21.2626 - y1_output_loss: 8.3354 - y2_output_loss: 12.8306 - y1_output_root_mean_squared_error: 2.8978 - y2_output_root_mean_squared_error: 3.5869 - val_loss: 19.5342 - val_y1_output_loss: 7.0288 - val_y2_output_loss: 11.9735 - val_y1_output_root_mean_squared_error: 2.6931 - val_y2_output_root_mean_squared_error: 3.5045
# Epoch 11/500
# 614/614 [==============================] - 0s 154us/sample - loss: 26.4094 - y1_output_loss: 9.3989 - y2_output_loss: 17.0986 - y1_output_root_mean_squared_error: 3.0520 - y2_output_root_mean_squared_error: 4.1346 - val_loss: 39.8414 - val_y1_output_loss: 12.4273 - val_y2_output_loss: 27.8138 - val_y1_output_root_mean_squared_error: 3.4968 - val_y2_output_root_mean_squared_error: 5.2549
# Epoch 12/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.3092 - y1_output_loss: 8.1308 - y2_output_loss: 11.3301 - y1_output_root_mean_squared_error: 2.8403 - y2_output_root_mean_squared_error: 3.3529 - val_loss: 22.6761 - val_y1_output_loss: 8.8500 - val_y2_output_loss: 13.9439 - val_y1_output_root_mean_squared_error: 2.9573 - val_y2_output_root_mean_squared_error: 3.7323
# Epoch 13/500
# 614/614 [==============================] - 0s 129us/sample - loss: 18.1265 - y1_output_loss: 7.6109 - y2_output_loss: 10.4655 - y1_output_root_mean_squared_error: 2.7564 - y2_output_root_mean_squared_error: 3.2448 - val_loss: 19.2665 - val_y1_output_loss: 7.7325 - val_y2_output_loss: 11.0030 - val_y1_output_root_mean_squared_error: 2.8297 - val_y2_output_root_mean_squared_error: 3.3555
# Epoch 14/500
# 614/614 [==============================] - 0s 150us/sample - loss: 16.5353 - y1_output_loss: 7.0619 - y2_output_loss: 9.3450 - y1_output_root_mean_squared_error: 2.6676 - y2_output_root_mean_squared_error: 3.0690 - val_loss: 23.6416 - val_y1_output_loss: 7.0435 - val_y2_output_loss: 16.6527 - val_y1_output_root_mean_squared_error: 2.6426 - val_y2_output_root_mean_squared_error: 4.0814
# Epoch 15/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.6930 - y1_output_loss: 6.9175 - y2_output_loss: 10.7401 - y1_output_root_mean_squared_error: 2.6324 - y2_output_root_mean_squared_error: 3.2808 - val_loss: 18.5107 - val_y1_output_loss: 6.7665 - val_y2_output_loss: 11.7010 - val_y1_output_root_mean_squared_error: 2.5974 - val_y2_output_root_mean_squared_error: 3.4299
# Epoch 16/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.4830 - y1_output_loss: 8.3702 - y2_output_loss: 14.9100 - y1_output_root_mean_squared_error: 2.9068 - y2_output_root_mean_squared_error: 3.8773 - val_loss: 20.7234 - val_y1_output_loss: 6.9104 - val_y2_output_loss: 13.3375 - val_y1_output_root_mean_squared_error: 2.6728 - val_y2_output_root_mean_squared_error: 3.6851
# Epoch 17/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.9430 - y1_output_loss: 6.7626 - y2_output_loss: 11.1125 - y1_output_root_mean_squared_error: 2.5966 - y2_output_root_mean_squared_error: 3.3468 - val_loss: 19.2837 - val_y1_output_loss: 7.9800 - val_y2_output_loss: 11.4324 - val_y1_output_root_mean_squared_error: 2.7980 - val_y2_output_root_mean_squared_error: 3.3845
# Epoch 18/500
# 614/614 [==============================] - 0s 146us/sample - loss: 19.8076 - y1_output_loss: 6.7477 - y2_output_loss: 13.0422 - y1_output_root_mean_squared_error: 2.5971 - y2_output_root_mean_squared_error: 3.6142 - val_loss: 14.1487 - val_y1_output_loss: 5.8863 - val_y2_output_loss: 7.9955 - val_y1_output_root_mean_squared_error: 2.4326 - val_y2_output_root_mean_squared_error: 2.8690
# Epoch 19/500
# 614/614 [==============================] - 0s 148us/sample - loss: 14.8850 - y1_output_loss: 6.0336 - y2_output_loss: 8.7512 - y1_output_root_mean_squared_error: 2.4649 - y2_output_root_mean_squared_error: 2.9680 - val_loss: 21.6192 - val_y1_output_loss: 5.0668 - val_y2_output_loss: 16.1778 - val_y1_output_root_mean_squared_error: 2.2744 - val_y2_output_root_mean_squared_error: 4.0554
# Epoch 20/500
# 614/614 [==============================] - 0s 144us/sample - loss: 15.1508 - y1_output_loss: 5.5885 - y2_output_loss: 9.4569 - y1_output_root_mean_squared_error: 2.3691 - y2_output_root_mean_squared_error: 3.0884 - val_loss: 13.9441 - val_y1_output_loss: 5.0354 - val_y2_output_loss: 8.7102 - val_y1_output_root_mean_squared_error: 2.2573 - val_y2_output_root_mean_squared_error: 2.9747
# Epoch 21/500
# 614/614 [==============================] - 0s 151us/sample - loss: 15.7926 - y1_output_loss: 5.5548 - y2_output_loss: 10.2721 - y1_output_root_mean_squared_error: 2.3653 - y2_output_root_mean_squared_error: 3.1934 - val_loss: 13.2911 - val_y1_output_loss: 4.9774 - val_y2_output_loss: 7.9934 - val_y1_output_root_mean_squared_error: 2.2559 - val_y2_output_root_mean_squared_error: 2.8640
# Epoch 22/500
# 614/614 [==============================] - 0s 141us/sample - loss: 14.9987 - y1_output_loss: 5.4122 - y2_output_loss: 9.5289 - y1_output_root_mean_squared_error: 2.3248 - y2_output_root_mean_squared_error: 3.0975 - val_loss: 12.8501 - val_y1_output_loss: 4.2620 - val_y2_output_loss: 8.3877 - val_y1_output_root_mean_squared_error: 2.0816 - val_y2_output_root_mean_squared_error: 2.9184
# Epoch 23/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.0787 - y1_output_loss: 5.0215 - y2_output_loss: 9.0438 - y1_output_root_mean_squared_error: 2.2270 - y2_output_root_mean_squared_error: 3.0198 - val_loss: 11.9289 - val_y1_output_loss: 4.8441 - val_y2_output_loss: 6.8025 - val_y1_output_root_mean_squared_error: 2.2237 - val_y2_output_root_mean_squared_error: 2.6427
# Epoch 24/500
# 614/614 [==============================] - 0s 146us/sample - loss: 12.3241 - y1_output_loss: 4.6959 - y2_output_loss: 7.7608 - y1_output_root_mean_squared_error: 2.1475 - y2_output_root_mean_squared_error: 2.7771 - val_loss: 21.1113 - val_y1_output_loss: 6.7005 - val_y2_output_loss: 14.8916 - val_y1_output_root_mean_squared_error: 2.5397 - val_y2_output_root_mean_squared_error: 3.8290
# Epoch 25/500
# 614/614 [==============================] - 0s 148us/sample - loss: 12.9753 - y1_output_loss: 4.7482 - y2_output_loss: 8.1216 - y1_output_root_mean_squared_error: 2.1881 - y2_output_root_mean_squared_error: 2.8614 - val_loss: 11.5415 - val_y1_output_loss: 4.5866 - val_y2_output_loss: 6.7990 - val_y1_output_root_mean_squared_error: 2.1411 - val_y2_output_root_mean_squared_error: 2.6376
# Epoch 26/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.1819 - y1_output_loss: 4.9190 - y2_output_loss: 9.1456 - y1_output_root_mean_squared_error: 2.2253 - y2_output_root_mean_squared_error: 3.0381 - val_loss: 10.4598 - val_y1_output_loss: 4.0746 - val_y2_output_loss: 6.1410 - val_y1_output_root_mean_squared_error: 2.0394 - val_y2_output_root_mean_squared_error: 2.5102
# Epoch 27/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.5159 - y1_output_loss: 4.1465 - y2_output_loss: 7.4830 - y1_output_root_mean_squared_error: 2.0362 - y2_output_root_mean_squared_error: 2.7148 - val_loss: 32.9443 - val_y1_output_loss: 10.8482 - val_y2_output_loss: 22.0049 - val_y1_output_root_mean_squared_error: 3.2913 - val_y2_output_root_mean_squared_error: 4.7023
# Epoch 28/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.2667 - y1_output_loss: 4.7384 - y2_output_loss: 8.4558 - y1_output_root_mean_squared_error: 2.1827 - y2_output_root_mean_squared_error: 2.9159 - val_loss: 9.4746 - val_y1_output_loss: 3.3572 - val_y2_output_loss: 5.9564 - val_y1_output_root_mean_squared_error: 1.8413 - val_y2_output_root_mean_squared_error: 2.4666
# Epoch 29/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.0425 - y1_output_loss: 3.5786 - y2_output_loss: 6.4393 - y1_output_root_mean_squared_error: 1.8935 - y2_output_root_mean_squared_error: 2.5411 - val_loss: 11.2634 - val_y1_output_loss: 4.1016 - val_y2_output_loss: 7.2505 - val_y1_output_root_mean_squared_error: 2.0120 - val_y2_output_root_mean_squared_error: 2.6861
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.2532 - y1_output_loss: 4.2240 - y2_output_loss: 8.0288 - y1_output_root_mean_squared_error: 2.0499 - y2_output_root_mean_squared_error: 2.8374 - val_loss: 17.3170 - val_y1_output_loss: 6.1706 - val_y2_output_loss: 11.4420 - val_y1_output_root_mean_squared_error: 2.4390 - val_y2_output_root_mean_squared_error: 3.3717
# Epoch 31/500
# 614/614 [==============================] - 0s 152us/sample - loss: 10.4986 - y1_output_loss: 3.3644 - y2_output_loss: 7.1250 - y1_output_root_mean_squared_error: 1.8390 - y2_output_root_mean_squared_error: 2.6677 - val_loss: 9.2844 - val_y1_output_loss: 3.6178 - val_y2_output_loss: 5.7737 - val_y1_output_root_mean_squared_error: 1.8700 - val_y2_output_root_mean_squared_error: 2.4058
# Epoch 32/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.0583 - y1_output_loss: 3.2912 - y2_output_loss: 5.8019 - y1_output_root_mean_squared_error: 1.8099 - y2_output_root_mean_squared_error: 2.4047 - val_loss: 10.3130 - val_y1_output_loss: 4.0295 - val_y2_output_loss: 6.3849 - val_y1_output_root_mean_squared_error: 1.9670 - val_y2_output_root_mean_squared_error: 2.5385
# Epoch 33/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.1909 - y1_output_loss: 3.1595 - y2_output_loss: 5.9657 - y1_output_root_mean_squared_error: 1.7859 - y2_output_root_mean_squared_error: 2.4498 - val_loss: 8.5170 - val_y1_output_loss: 3.0314 - val_y2_output_loss: 5.4490 - val_y1_output_root_mean_squared_error: 1.7426 - val_y2_output_root_mean_squared_error: 2.3410
# Epoch 34/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.9767 - y1_output_loss: 2.7612 - y2_output_loss: 5.1518 - y1_output_root_mean_squared_error: 1.6686 - y2_output_root_mean_squared_error: 2.2787 - val_loss: 7.8623 - val_y1_output_loss: 2.7486 - val_y2_output_loss: 5.0789 - val_y1_output_root_mean_squared_error: 1.6500 - val_y2_output_root_mean_squared_error: 2.2671
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.2253 - y1_output_loss: 3.3498 - y2_output_loss: 6.9576 - y1_output_root_mean_squared_error: 1.8141 - y2_output_root_mean_squared_error: 2.6333 - val_loss: 21.5583 - val_y1_output_loss: 8.8561 - val_y2_output_loss: 12.0726 - val_y1_output_root_mean_squared_error: 3.0162 - val_y2_output_root_mean_squared_error: 3.5300
# Epoch 36/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.4177 - y1_output_loss: 2.9104 - y2_output_loss: 6.4322 - y1_output_root_mean_squared_error: 1.7113 - y2_output_root_mean_squared_error: 2.5474 - val_loss: 8.3666 - val_y1_output_loss: 3.2981 - val_y2_output_loss: 5.1790 - val_y1_output_root_mean_squared_error: 1.7746 - val_y2_output_root_mean_squared_error: 2.2842
# Epoch 37/500
# 614/614 [==============================] - 0s 153us/sample - loss: 7.9237 - y1_output_loss: 2.5504 - y2_output_loss: 5.5436 - y1_output_root_mean_squared_error: 1.5931 - y2_output_root_mean_squared_error: 2.3207 - val_loss: 31.2351 - val_y1_output_loss: 5.8275 - val_y2_output_loss: 24.9225 - val_y1_output_root_mean_squared_error: 2.4461 - val_y2_output_root_mean_squared_error: 5.0251
# Epoch 38/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.6549 - y1_output_loss: 2.5688 - y2_output_loss: 6.0254 - y1_output_root_mean_squared_error: 1.6078 - y2_output_root_mean_squared_error: 2.4637 - val_loss: 9.4873 - val_y1_output_loss: 2.5482 - val_y2_output_loss: 7.0732 - val_y1_output_root_mean_squared_error: 1.5778 - val_y2_output_root_mean_squared_error: 2.6453
# Epoch 39/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.3731 - y1_output_loss: 2.4825 - y2_output_loss: 5.8242 - y1_output_root_mean_squared_error: 1.5821 - y2_output_root_mean_squared_error: 2.4228 - val_loss: 7.6236 - val_y1_output_loss: 2.7468 - val_y2_output_loss: 4.9951 - val_y1_output_root_mean_squared_error: 1.6265 - val_y2_output_root_mean_squared_error: 2.2311
# Epoch 40/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.1687 - y1_output_loss: 2.3083 - y2_output_loss: 4.9885 - y1_output_root_mean_squared_error: 1.5166 - y2_output_root_mean_squared_error: 2.2065 - val_loss: 24.3351 - val_y1_output_loss: 6.7028 - val_y2_output_loss: 17.1866 - val_y1_output_root_mean_squared_error: 2.6268 - val_y2_output_root_mean_squared_error: 4.1756
# Epoch 41/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.0586 - y1_output_loss: 2.3525 - y2_output_loss: 4.8985 - y1_output_root_mean_squared_error: 1.5232 - y2_output_root_mean_squared_error: 2.1768 - val_loss: 45.6262 - val_y1_output_loss: 8.5220 - val_y2_output_loss: 36.5842 - val_y1_output_root_mean_squared_error: 2.9533 - val_y2_output_root_mean_squared_error: 6.0749
# Epoch 42/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.6600 - y1_output_loss: 2.8414 - y2_output_loss: 6.7786 - y1_output_root_mean_squared_error: 1.6893 - y2_output_root_mean_squared_error: 2.6089 - val_loss: 9.4071 - val_y1_output_loss: 3.2047 - val_y2_output_loss: 6.1301 - val_y1_output_root_mean_squared_error: 1.7911 - val_y2_output_root_mean_squared_error: 2.4898
# Epoch 43/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.3739 - y1_output_loss: 2.5827 - y2_output_loss: 6.7120 - y1_output_root_mean_squared_error: 1.6117 - y2_output_root_mean_squared_error: 2.6031 - val_loss: 9.4232 - val_y1_output_loss: 3.3528 - val_y2_output_loss: 6.4061 - val_y1_output_root_mean_squared_error: 1.7708 - val_y2_output_root_mean_squared_error: 2.5075
# Epoch 44/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.2512 - y1_output_loss: 2.0949 - y2_output_loss: 5.1364 - y1_output_root_mean_squared_error: 1.4462 - y2_output_root_mean_squared_error: 2.2715 - val_loss: 5.8381 - val_y1_output_loss: 2.0223 - val_y2_output_loss: 3.8314 - val_y1_output_root_mean_squared_error: 1.4123 - val_y2_output_root_mean_squared_error: 1.9605
# Epoch 45/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.3438 - y1_output_loss: 2.2555 - y2_output_loss: 5.0791 - y1_output_root_mean_squared_error: 1.4971 - y2_output_root_mean_squared_error: 2.2589 - val_loss: 7.0294 - val_y1_output_loss: 2.0652 - val_y2_output_loss: 5.0591 - val_y1_output_root_mean_squared_error: 1.4160 - val_y2_output_root_mean_squared_error: 2.2415
# Epoch 46/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.2591 - y1_output_loss: 2.2177 - y2_output_loss: 5.0600 - y1_output_root_mean_squared_error: 1.4897 - y2_output_root_mean_squared_error: 2.2449 - val_loss: 6.1759 - val_y1_output_loss: 2.2072 - val_y2_output_loss: 3.8948 - val_y1_output_root_mean_squared_error: 1.4941 - val_y2_output_root_mean_squared_error: 1.9859
# Epoch 47/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.6205 - y1_output_loss: 1.8880 - y2_output_loss: 4.7382 - y1_output_root_mean_squared_error: 1.3773 - y2_output_root_mean_squared_error: 2.1734 - val_loss: 5.8581 - val_y1_output_loss: 2.2249 - val_y2_output_loss: 3.6053 - val_y1_output_root_mean_squared_error: 1.5059 - val_y2_output_root_mean_squared_error: 1.8948
# Epoch 48/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.7617 - y1_output_loss: 1.9610 - y2_output_loss: 4.8821 - y1_output_root_mean_squared_error: 1.4006 - y2_output_root_mean_squared_error: 2.1909 - val_loss: 9.0832 - val_y1_output_loss: 3.3987 - val_y2_output_loss: 5.5471 - val_y1_output_root_mean_squared_error: 1.8641 - val_y2_output_root_mean_squared_error: 2.3682
# Epoch 49/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.8042 - y1_output_loss: 1.9579 - y2_output_loss: 4.8816 - y1_output_root_mean_squared_error: 1.4057 - y2_output_root_mean_squared_error: 2.1973 - val_loss: 14.8104 - val_y1_output_loss: 4.0719 - val_y2_output_loss: 10.8258 - val_y1_output_root_mean_squared_error: 2.0046 - val_y2_output_root_mean_squared_error: 3.2851
# Epoch 50/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.3267 - y1_output_loss: 1.8390 - y2_output_loss: 4.5081 - y1_output_root_mean_squared_error: 1.3590 - y2_output_root_mean_squared_error: 2.1166 - val_loss: 11.8557 - val_y1_output_loss: 3.2998 - val_y2_output_loss: 8.9959 - val_y1_output_root_mean_squared_error: 1.7605 - val_y2_output_root_mean_squared_error: 2.9591
# Epoch 51/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.0696 - y1_output_loss: 1.8331 - y2_output_loss: 4.3557 - y1_output_root_mean_squared_error: 1.3407 - y2_output_root_mean_squared_error: 2.0669 - val_loss: 31.3070 - val_y1_output_loss: 10.6641 - val_y2_output_loss: 20.8793 - val_y1_output_root_mean_squared_error: 3.2448 - val_y2_output_root_mean_squared_error: 4.5583
# Epoch 52/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.8847 - y1_output_loss: 2.6178 - y2_output_loss: 6.5752 - y1_output_root_mean_squared_error: 1.5637 - y2_output_root_mean_squared_error: 2.5376 - val_loss: 43.7923 - val_y1_output_loss: 14.5082 - val_y2_output_loss: 28.1028 - val_y1_output_root_mean_squared_error: 3.8770 - val_y2_output_root_mean_squared_error: 5.3629
# Epoch 53/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.1142 - y1_output_loss: 1.9921 - y2_output_loss: 5.1018 - y1_output_root_mean_squared_error: 1.4061 - y2_output_root_mean_squared_error: 2.2665 - val_loss: 9.4879 - val_y1_output_loss: 3.3743 - val_y2_output_loss: 6.3912 - val_y1_output_root_mean_squared_error: 1.7975 - val_y2_output_root_mean_squared_error: 2.5013
# Epoch 54/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8666 - y1_output_loss: 1.3216 - y2_output_loss: 3.5873 - y1_output_root_mean_squared_error: 1.1418 - y2_output_root_mean_squared_error: 1.8875 - val_loss: 9.8456 - val_y1_output_loss: 2.9203 - val_y2_output_loss: 6.8667 - val_y1_output_root_mean_squared_error: 1.7330 - val_y2_output_root_mean_squared_error: 2.6158
# Epoch 55/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.5713 - y1_output_loss: 1.5403 - y2_output_loss: 3.9918 - y1_output_root_mean_squared_error: 1.2465 - y2_output_root_mean_squared_error: 2.0044 - val_loss: 4.9123 - val_y1_output_loss: 1.5166 - val_y2_output_loss: 3.4264 - val_y1_output_root_mean_squared_error: 1.2129 - val_y2_output_root_mean_squared_error: 1.8550
# Epoch 56/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.9281 - y1_output_loss: 1.3035 - y2_output_loss: 3.6695 - y1_output_root_mean_squared_error: 1.1428 - y2_output_root_mean_squared_error: 1.9032 - val_loss: 4.8658 - val_y1_output_loss: 1.2221 - val_y2_output_loss: 3.6931 - val_y1_output_root_mean_squared_error: 1.1017 - val_y2_output_root_mean_squared_error: 1.9110
# Epoch 57/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.7041 - y1_output_loss: 1.8977 - y2_output_loss: 4.8240 - y1_output_root_mean_squared_error: 1.3696 - y2_output_root_mean_squared_error: 2.1973 - val_loss: 9.7786 - val_y1_output_loss: 4.4179 - val_y2_output_loss: 5.1891 - val_y1_output_root_mean_squared_error: 2.1341 - val_y2_output_root_mean_squared_error: 2.2856
# Epoch 58/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.1255 - y1_output_loss: 1.3292 - y2_output_loss: 3.7625 - y1_output_root_mean_squared_error: 1.1583 - y2_output_root_mean_squared_error: 1.9452 - val_loss: 4.4055 - val_y1_output_loss: 1.3458 - val_y2_output_loss: 3.1417 - val_y1_output_root_mean_squared_error: 1.1556 - val_y2_output_root_mean_squared_error: 1.7522
# Epoch 59/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.9547 - y1_output_loss: 1.7508 - y2_output_loss: 5.1573 - y1_output_root_mean_squared_error: 1.3263 - y2_output_root_mean_squared_error: 2.2794 - val_loss: 9.1125 - val_y1_output_loss: 2.9732 - val_y2_output_loss: 6.4265 - val_y1_output_root_mean_squared_error: 1.6864 - val_y2_output_root_mean_squared_error: 2.5037
# Epoch 60/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.2230 - y1_output_loss: 1.2902 - y2_output_loss: 3.9122 - y1_output_root_mean_squared_error: 1.1410 - y2_output_root_mean_squared_error: 1.9802 - val_loss: 6.0350 - val_y1_output_loss: 2.2447 - val_y2_output_loss: 3.9285 - val_y1_output_root_mean_squared_error: 1.4750 - val_y2_output_root_mean_squared_error: 1.9645
# Epoch 61/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.8295 - y1_output_loss: 1.8167 - y2_output_loss: 4.9564 - y1_output_root_mean_squared_error: 1.3541 - y2_output_root_mean_squared_error: 2.2351 - val_loss: 4.2514 - val_y1_output_loss: 1.1342 - val_y2_output_loss: 3.1024 - val_y1_output_root_mean_squared_error: 1.0596 - val_y2_output_root_mean_squared_error: 1.7688
# Epoch 62/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.9325 - y1_output_loss: 1.1799 - y2_output_loss: 3.7360 - y1_output_root_mean_squared_error: 1.0902 - y2_output_root_mean_squared_error: 1.9349 - val_loss: 4.9919 - val_y1_output_loss: 1.5831 - val_y2_output_loss: 3.4511 - val_y1_output_root_mean_squared_error: 1.2632 - val_y2_output_root_mean_squared_error: 1.8429
# Epoch 63/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6031 - y1_output_loss: 1.2109 - y2_output_loss: 3.3820 - y1_output_root_mean_squared_error: 1.0969 - y2_output_root_mean_squared_error: 1.8439 - val_loss: 12.1116 - val_y1_output_loss: 4.6662 - val_y2_output_loss: 7.1988 - val_y1_output_root_mean_squared_error: 2.1977 - val_y2_output_root_mean_squared_error: 2.6985
# Epoch 64/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.7176 - y1_output_loss: 1.2680 - y2_output_loss: 3.4416 - y1_output_root_mean_squared_error: 1.1200 - y2_output_root_mean_squared_error: 1.8610 - val_loss: 5.3979 - val_y1_output_loss: 1.6716 - val_y2_output_loss: 3.7715 - val_y1_output_root_mean_squared_error: 1.2828 - val_y2_output_root_mean_squared_error: 1.9371
# Epoch 65/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.6254 - y1_output_loss: 1.0511 - y2_output_loss: 3.5370 - y1_output_root_mean_squared_error: 1.0289 - y2_output_root_mean_squared_error: 1.8886 - val_loss: 4.5697 - val_y1_output_loss: 0.9439 - val_y2_output_loss: 3.6592 - val_y1_output_root_mean_squared_error: 0.9710 - val_y2_output_root_mean_squared_error: 1.9044
# Epoch 66/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7912 - y1_output_loss: 0.9276 - y2_output_loss: 2.8452 - y1_output_root_mean_squared_error: 0.9648 - y2_output_root_mean_squared_error: 1.6913 - val_loss: 3.4433 - val_y1_output_loss: 0.7902 - val_y2_output_loss: 2.6758 - val_y1_output_root_mean_squared_error: 0.8875 - val_y2_output_root_mean_squared_error: 1.6296
# Epoch 67/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.4317 - y1_output_loss: 0.7684 - y2_output_loss: 2.6423 - y1_output_root_mean_squared_error: 0.8804 - y2_output_root_mean_squared_error: 1.6299 - val_loss: 3.8794 - val_y1_output_loss: 0.8543 - val_y2_output_loss: 3.0492 - val_y1_output_root_mean_squared_error: 0.9238 - val_y2_output_root_mean_squared_error: 1.7396
# Epoch 68/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.5672 - y1_output_loss: 1.8899 - y2_output_loss: 5.6965 - y1_output_root_mean_squared_error: 1.3795 - y2_output_root_mean_squared_error: 2.3800 - val_loss: 4.4699 - val_y1_output_loss: 1.3528 - val_y2_output_loss: 3.1589 - val_y1_output_root_mean_squared_error: 1.1585 - val_y2_output_root_mean_squared_error: 1.7686
# Epoch 69/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8565 - y1_output_loss: 1.0393 - y2_output_loss: 3.8254 - y1_output_root_mean_squared_error: 1.0205 - y2_output_root_mean_squared_error: 1.9533 - val_loss: 14.6140 - val_y1_output_loss: 2.8760 - val_y2_output_loss: 11.8127 - val_y1_output_root_mean_squared_error: 1.7022 - val_y2_output_root_mean_squared_error: 3.4229
# Epoch 70/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7026 - y1_output_loss: 1.9208 - y2_output_loss: 5.7305 - y1_output_root_mean_squared_error: 1.3918 - y2_output_root_mean_squared_error: 2.4012 - val_loss: 7.2407 - val_y1_output_loss: 0.9755 - val_y2_output_loss: 6.3565 - val_y1_output_root_mean_squared_error: 0.9939 - val_y2_output_root_mean_squared_error: 2.5006
# Epoch 71/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.7209 - y1_output_loss: 0.7749 - y2_output_loss: 2.9301 - y1_output_root_mean_squared_error: 0.8831 - y2_output_root_mean_squared_error: 1.7150 - val_loss: 2.8431 - val_y1_output_loss: 0.5964 - val_y2_output_loss: 2.2780 - val_y1_output_root_mean_squared_error: 0.7688 - val_y2_output_root_mean_squared_error: 1.5007
# Epoch 72/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.0175 - y1_output_loss: 0.8055 - y2_output_loss: 3.2295 - y1_output_root_mean_squared_error: 0.9015 - y2_output_root_mean_squared_error: 1.7902 - val_loss: 6.4987 - val_y1_output_loss: 0.9705 - val_y2_output_loss: 5.5475 - val_y1_output_root_mean_squared_error: 0.9920 - val_y2_output_root_mean_squared_error: 2.3483
# Epoch 73/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.2877 - y1_output_loss: 0.9100 - y2_output_loss: 3.3807 - y1_output_root_mean_squared_error: 0.9533 - y2_output_root_mean_squared_error: 1.8382 - val_loss: 6.5236 - val_y1_output_loss: 1.1202 - val_y2_output_loss: 5.3669 - val_y1_output_root_mean_squared_error: 1.0648 - val_y2_output_root_mean_squared_error: 2.3216
# Epoch 74/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.6672 - y1_output_loss: 1.5248 - y2_output_loss: 4.1088 - y1_output_root_mean_squared_error: 1.2405 - y2_output_root_mean_squared_error: 2.0318 - val_loss: 8.1498 - val_y1_output_loss: 1.4076 - val_y2_output_loss: 6.7311 - val_y1_output_root_mean_squared_error: 1.1979 - val_y2_output_root_mean_squared_error: 2.5913
# Epoch 75/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.3537 - y1_output_loss: 0.9226 - y2_output_loss: 3.3917 - y1_output_root_mean_squared_error: 0.9644 - y2_output_root_mean_squared_error: 1.8503 - val_loss: 3.0695 - val_y1_output_loss: 0.7423 - val_y2_output_loss: 2.3472 - val_y1_output_root_mean_squared_error: 0.8634 - val_y2_output_root_mean_squared_error: 1.5245
# Epoch 76/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.2840 - y1_output_loss: 0.7911 - y2_output_loss: 2.5311 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.5784 - val_loss: 3.5944 - val_y1_output_loss: 0.9955 - val_y2_output_loss: 2.6109 - val_y1_output_root_mean_squared_error: 0.9994 - val_y2_output_root_mean_squared_error: 1.6111
# Epoch 77/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.5178 - y1_output_loss: 1.0371 - y2_output_loss: 3.4777 - y1_output_root_mean_squared_error: 1.0131 - y2_output_root_mean_squared_error: 1.8685 - val_loss: 13.0624 - val_y1_output_loss: 3.8806 - val_y2_output_loss: 9.1107 - val_y1_output_root_mean_squared_error: 1.9799 - val_y2_output_root_mean_squared_error: 3.0236
# Epoch 78/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.5245 - y1_output_loss: 0.8268 - y2_output_loss: 2.7016 - y1_output_root_mean_squared_error: 0.9130 - y2_output_root_mean_squared_error: 1.6404 - val_loss: 3.3079 - val_y1_output_loss: 0.6230 - val_y2_output_loss: 2.7562 - val_y1_output_root_mean_squared_error: 0.7824 - val_y2_output_root_mean_squared_error: 1.6419
# Epoch 79/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.6038 - y1_output_loss: 0.8342 - y2_output_loss: 2.7904 - y1_output_root_mean_squared_error: 0.9162 - y2_output_root_mean_squared_error: 1.6627 - val_loss: 4.8076 - val_y1_output_loss: 0.6415 - val_y2_output_loss: 4.2332 - val_y1_output_root_mean_squared_error: 0.8012 - val_y2_output_root_mean_squared_error: 2.0410
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6064 - y1_output_loss: 1.1272 - y2_output_loss: 3.4516 - y1_output_root_mean_squared_error: 1.0636 - y2_output_root_mean_squared_error: 1.8642 - val_loss: 4.3967 - val_y1_output_loss: 1.4494 - val_y2_output_loss: 2.9807 - val_y1_output_root_mean_squared_error: 1.2009 - val_y2_output_root_mean_squared_error: 1.7189
# Epoch 81/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.3496 - y1_output_loss: 0.7935 - y2_output_loss: 2.5388 - y1_output_root_mean_squared_error: 0.8897 - y2_output_root_mean_squared_error: 1.5994 - val_loss: 3.9062 - val_y1_output_loss: 0.9496 - val_y2_output_loss: 2.9436 - val_y1_output_root_mean_squared_error: 0.9800 - val_y2_output_root_mean_squared_error: 1.7163
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0877 - y1_output_loss: 0.7077 - y2_output_loss: 2.3627 - y1_output_root_mean_squared_error: 0.8451 - y2_output_root_mean_squared_error: 1.5406 - val_loss: 3.0092 - val_y1_output_loss: 0.7908 - val_y2_output_loss: 2.2566 - val_y1_output_root_mean_squared_error: 0.8922 - val_y2_output_root_mean_squared_error: 1.4877
# Epoch 83/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.2557 - y1_output_loss: 0.6877 - y2_output_loss: 2.5624 - y1_output_root_mean_squared_error: 0.8256 - y2_output_root_mean_squared_error: 1.6044 - val_loss: 3.4969 - val_y1_output_loss: 1.2356 - val_y2_output_loss: 2.3076 - val_y1_output_root_mean_squared_error: 1.1097 - val_y2_output_root_mean_squared_error: 1.5051
# Epoch 84/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.9769 - y1_output_loss: 0.8833 - y2_output_loss: 3.0711 - y1_output_root_mean_squared_error: 0.9440 - y2_output_root_mean_squared_error: 1.7566 - val_loss: 3.7482 - val_y1_output_loss: 0.7268 - val_y2_output_loss: 3.0283 - val_y1_output_root_mean_squared_error: 0.8467 - val_y2_output_root_mean_squared_error: 1.7411
# Epoch 85/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.9612 - y1_output_loss: 0.8714 - y2_output_loss: 3.0578 - y1_output_root_mean_squared_error: 0.9364 - y2_output_root_mean_squared_error: 1.7562 - val_loss: 3.5965 - val_y1_output_loss: 1.1245 - val_y2_output_loss: 2.4878 - val_y1_output_root_mean_squared_error: 1.0619 - val_y2_output_root_mean_squared_error: 1.5713
# Epoch 86/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.1224 - y1_output_loss: 0.6385 - y2_output_loss: 2.5013 - y1_output_root_mean_squared_error: 0.8028 - y2_output_root_mean_squared_error: 1.5742 - val_loss: 7.7232 - val_y1_output_loss: 1.0315 - val_y2_output_loss: 6.7218 - val_y1_output_root_mean_squared_error: 1.0249 - val_y2_output_root_mean_squared_error: 2.5832
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.6655 - y1_output_loss: 2.4161 - y2_output_loss: 5.2142 - y1_output_root_mean_squared_error: 1.5608 - y2_output_root_mean_squared_error: 2.2868 - val_loss: 8.1346 - val_y1_output_loss: 1.0080 - val_y2_output_loss: 7.1271 - val_y1_output_root_mean_squared_error: 1.0076 - val_y2_output_root_mean_squared_error: 2.6682
# Epoch 88/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.6023 - y1_output_loss: 1.0531 - y2_output_loss: 3.5299 - y1_output_root_mean_squared_error: 1.0288 - y2_output_root_mean_squared_error: 1.8825 - val_loss: 4.4519 - val_y1_output_loss: 1.4823 - val_y2_output_loss: 2.9365 - val_y1_output_root_mean_squared_error: 1.2270 - val_y2_output_root_mean_squared_error: 1.7165
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2461 - y1_output_loss: 0.6844 - y2_output_loss: 2.5525 - y1_output_root_mean_squared_error: 0.8283 - y2_output_root_mean_squared_error: 1.6000 - val_loss: 3.9802 - val_y1_output_loss: 0.9485 - val_y2_output_loss: 3.0389 - val_y1_output_root_mean_squared_error: 0.9762 - val_y2_output_root_mean_squared_error: 1.7399
# Epoch 90/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5161 - y1_output_loss: 0.5223 - y2_output_loss: 1.9792 - y1_output_root_mean_squared_error: 0.7247 - y2_output_root_mean_squared_error: 1.4110 - val_loss: 2.8875 - val_y1_output_loss: 0.4690 - val_y2_output_loss: 2.4464 - val_y1_output_root_mean_squared_error: 0.6884 - val_y2_output_root_mean_squared_error: 1.5536
# Epoch 91/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3425 - y1_output_loss: 0.6574 - y2_output_loss: 2.7874 - y1_output_root_mean_squared_error: 0.8117 - y2_output_root_mean_squared_error: 1.6382 - val_loss: 7.8838 - val_y1_output_loss: 1.8457 - val_y2_output_loss: 6.0590 - val_y1_output_root_mean_squared_error: 1.3753 - val_y2_output_root_mean_squared_error: 2.4479
# Epoch 92/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.3448 - y1_output_loss: 1.2311 - y2_output_loss: 3.0959 - y1_output_root_mean_squared_error: 1.1117 - y2_output_root_mean_squared_error: 1.7632 - val_loss: 2.9341 - val_y1_output_loss: 0.5786 - val_y2_output_loss: 2.3836 - val_y1_output_root_mean_squared_error: 0.7630 - val_y2_output_root_mean_squared_error: 1.5336
# Epoch 93/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.5602 - y1_output_loss: 0.9320 - y2_output_loss: 2.6168 - y1_output_root_mean_squared_error: 0.9696 - y2_output_root_mean_squared_error: 1.6187 - val_loss: 4.4244 - val_y1_output_loss: 1.3369 - val_y2_output_loss: 3.0444 - val_y1_output_root_mean_squared_error: 1.1698 - val_y2_output_root_mean_squared_error: 1.7481
# Epoch 94/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.9171 - y1_output_loss: 0.7015 - y2_output_loss: 2.2066 - y1_output_root_mean_squared_error: 0.8341 - y2_output_root_mean_squared_error: 1.4904 - val_loss: 4.6360 - val_y1_output_loss: 1.3022 - val_y2_output_loss: 3.3650 - val_y1_output_root_mean_squared_error: 1.1434 - val_y2_output_root_mean_squared_error: 1.8244
# Epoch 95/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.8718 - y1_output_loss: 0.5667 - y2_output_loss: 2.3215 - y1_output_root_mean_squared_error: 0.7543 - y2_output_root_mean_squared_error: 1.5175 - val_loss: 2.9798 - val_y1_output_loss: 0.5688 - val_y2_output_loss: 2.4148 - val_y1_output_root_mean_squared_error: 0.7563 - val_y2_output_root_mean_squared_error: 1.5517
# Epoch 96/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9390 - y1_output_loss: 0.6886 - y2_output_loss: 2.2604 - y1_output_root_mean_squared_error: 0.8299 - y2_output_root_mean_squared_error: 1.5001 - val_loss: 7.0462 - val_y1_output_loss: 0.9433 - val_y2_output_loss: 6.1376 - val_y1_output_root_mean_squared_error: 0.9734 - val_y2_output_root_mean_squared_error: 2.4696
# Epoch 97/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6067 - y1_output_loss: 0.9751 - y2_output_loss: 3.5938 - y1_output_root_mean_squared_error: 0.9900 - y2_output_root_mean_squared_error: 1.9044 - val_loss: 3.5675 - val_y1_output_loss: 0.9496 - val_y2_output_loss: 2.6328 - val_y1_output_root_mean_squared_error: 0.9760 - val_y2_output_root_mean_squared_error: 1.6171
# Epoch 98/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.8692 - y1_output_loss: 0.6788 - y2_output_loss: 2.1838 - y1_output_root_mean_squared_error: 0.8250 - y2_output_root_mean_squared_error: 1.4794 - val_loss: 2.5263 - val_y1_output_loss: 0.5041 - val_y2_output_loss: 2.0448 - val_y1_output_root_mean_squared_error: 0.7145 - val_y2_output_root_mean_squared_error: 1.4198
# Epoch 99/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7413 - y1_output_loss: 0.6075 - y2_output_loss: 2.1178 - y1_output_root_mean_squared_error: 0.7785 - y2_output_root_mean_squared_error: 1.4613 - val_loss: 3.3550 - val_y1_output_loss: 0.5569 - val_y2_output_loss: 2.8544 - val_y1_output_root_mean_squared_error: 0.7382 - val_y2_output_root_mean_squared_error: 1.6763
# Epoch 100/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.0957 - y1_output_loss: 0.6942 - y2_output_loss: 2.3721 - y1_output_root_mean_squared_error: 0.8371 - y2_output_root_mean_squared_error: 1.5476 - val_loss: 2.6001 - val_y1_output_loss: 0.5565 - val_y2_output_loss: 2.0568 - val_y1_output_root_mean_squared_error: 0.7526 - val_y2_output_root_mean_squared_error: 1.4261
# Epoch 101/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3700 - y1_output_loss: 0.7887 - y2_output_loss: 2.5665 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.6053 - val_loss: 3.9657 - val_y1_output_loss: 0.9932 - val_y2_output_loss: 2.9929 - val_y1_output_root_mean_squared_error: 0.9972 - val_y2_output_root_mean_squared_error: 1.7237
# Epoch 102/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.3915 - y1_output_loss: 0.5484 - y2_output_loss: 1.8236 - y1_output_root_mean_squared_error: 0.7433 - y2_output_root_mean_squared_error: 1.3561 - val_loss: 2.6535 - val_y1_output_loss: 0.5457 - val_y2_output_loss: 2.1249 - val_y1_output_root_mean_squared_error: 0.7395 - val_y2_output_root_mean_squared_error: 1.4514
# Epoch 103/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.1304 - y1_output_loss: 0.5125 - y2_output_loss: 2.6187 - y1_output_root_mean_squared_error: 0.7163 - y2_output_root_mean_squared_error: 1.6178 - val_loss: 3.7525 - val_y1_output_loss: 1.5053 - val_y2_output_loss: 2.2285 - val_y1_output_root_mean_squared_error: 1.2424 - val_y2_output_root_mean_squared_error: 1.4863
# Epoch 104/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6642 - y1_output_loss: 0.5677 - y2_output_loss: 2.0837 - y1_output_root_mean_squared_error: 0.7514 - y2_output_root_mean_squared_error: 1.4490 - val_loss: 2.4151 - val_y1_output_loss: 0.5091 - val_y2_output_loss: 1.9423 - val_y1_output_root_mean_squared_error: 0.7170 - val_y2_output_root_mean_squared_error: 1.3788
# Epoch 105/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.8320 - y1_output_loss: 0.8465 - y2_output_loss: 2.9788 - y1_output_root_mean_squared_error: 0.9175 - y2_output_root_mean_squared_error: 1.7292 - val_loss: 7.6129 - val_y1_output_loss: 2.4999 - val_y2_output_loss: 5.0213 - val_y1_output_root_mean_squared_error: 1.5959 - val_y2_output_root_mean_squared_error: 2.2508
# Epoch 106/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.5672 - y1_output_loss: 0.5522 - y2_output_loss: 2.0011 - y1_output_root_mean_squared_error: 0.7430 - y2_output_root_mean_squared_error: 1.4196 - val_loss: 2.4702 - val_y1_output_loss: 0.5245 - val_y2_output_loss: 1.9465 - val_y1_output_root_mean_squared_error: 0.7268 - val_y2_output_root_mean_squared_error: 1.3936
# Epoch 107/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5352 - y1_output_loss: 0.5156 - y2_output_loss: 2.0337 - y1_output_root_mean_squared_error: 0.7154 - y2_output_root_mean_squared_error: 1.4225 - val_loss: 3.5988 - val_y1_output_loss: 0.4685 - val_y2_output_loss: 3.1424 - val_y1_output_root_mean_squared_error: 0.6900 - val_y2_output_root_mean_squared_error: 1.7671
# Epoch 108/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9235 - y1_output_loss: 0.6452 - y2_output_loss: 2.2594 - y1_output_root_mean_squared_error: 0.8044 - y2_output_root_mean_squared_error: 1.5088 - val_loss: 3.2554 - val_y1_output_loss: 0.7539 - val_y2_output_loss: 2.4927 - val_y1_output_root_mean_squared_error: 0.8770 - val_y2_output_root_mean_squared_error: 1.5768
# Epoch 109/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.3371 - y1_output_loss: 0.7418 - y2_output_loss: 2.5918 - y1_output_root_mean_squared_error: 0.8571 - y2_output_root_mean_squared_error: 1.6132 - val_loss: 3.0610 - val_y1_output_loss: 0.9660 - val_y2_output_loss: 2.1280 - val_y1_output_root_mean_squared_error: 0.9844 - val_y2_output_root_mean_squared_error: 1.4464
# Epoch 110/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4396 - y1_output_loss: 0.5564 - y2_output_loss: 1.8794 - y1_output_root_mean_squared_error: 0.7469 - y2_output_root_mean_squared_error: 1.3718 - val_loss: 3.5361 - val_y1_output_loss: 0.5589 - val_y2_output_loss: 3.0422 - val_y1_output_root_mean_squared_error: 0.7424 - val_y2_output_root_mean_squared_error: 1.7277
# Epoch 111/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1818 - y1_output_loss: 0.4805 - y2_output_loss: 1.6975 - y1_output_root_mean_squared_error: 0.6946 - y2_output_root_mean_squared_error: 1.3036 - val_loss: 4.1274 - val_y1_output_loss: 1.1066 - val_y2_output_loss: 3.0067 - val_y1_output_root_mean_squared_error: 1.0583 - val_y2_output_root_mean_squared_error: 1.7342
# Epoch 112/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5546 - y1_output_loss: 0.5019 - y2_output_loss: 2.0286 - y1_output_root_mean_squared_error: 0.7119 - y2_output_root_mean_squared_error: 1.4310 - val_loss: 2.2940 - val_y1_output_loss: 0.4108 - val_y2_output_loss: 1.9590 - val_y1_output_root_mean_squared_error: 0.6408 - val_y2_output_root_mean_squared_error: 1.3724
# Epoch 113/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6746 - y1_output_loss: 0.6041 - y2_output_loss: 2.0482 - y1_output_root_mean_squared_error: 0.7795 - y2_output_root_mean_squared_error: 1.4377 - val_loss: 2.2781 - val_y1_output_loss: 0.4387 - val_y2_output_loss: 1.8439 - val_y1_output_root_mean_squared_error: 0.6626 - val_y2_output_root_mean_squared_error: 1.3561
# Epoch 114/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4136 - y1_output_loss: 0.5078 - y2_output_loss: 1.8988 - y1_output_root_mean_squared_error: 0.7139 - y2_output_root_mean_squared_error: 1.3799 - val_loss: 2.5462 - val_y1_output_loss: 0.4553 - val_y2_output_loss: 2.0812 - val_y1_output_root_mean_squared_error: 0.6758 - val_y2_output_root_mean_squared_error: 1.4455
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2578 - y1_output_loss: 0.4538 - y2_output_loss: 1.7924 - y1_output_root_mean_squared_error: 0.6721 - y2_output_root_mean_squared_error: 1.3439 - val_loss: 2.7833 - val_y1_output_loss: 0.5980 - val_y2_output_loss: 2.1831 - val_y1_output_root_mean_squared_error: 0.7816 - val_y2_output_root_mean_squared_error: 1.4739
# Epoch 116/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3425 - y1_output_loss: 0.6744 - y2_output_loss: 2.7321 - y1_output_root_mean_squared_error: 0.8205 - y2_output_root_mean_squared_error: 1.6338 - val_loss: 5.7173 - val_y1_output_loss: 0.5443 - val_y2_output_loss: 5.1564 - val_y1_output_root_mean_squared_error: 0.7439 - val_y2_output_root_mean_squared_error: 2.2724
# Epoch 117/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3470 - y1_output_loss: 0.5224 - y2_output_loss: 1.8447 - y1_output_root_mean_squared_error: 0.7233 - y2_output_root_mean_squared_error: 1.3505 - val_loss: 3.7607 - val_y1_output_loss: 0.4118 - val_y2_output_loss: 3.4184 - val_y1_output_root_mean_squared_error: 0.6401 - val_y2_output_root_mean_squared_error: 1.8306
# Epoch 118/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4283 - y1_output_loss: 0.5001 - y2_output_loss: 1.9096 - y1_output_root_mean_squared_error: 0.7083 - y2_output_root_mean_squared_error: 1.3880 - val_loss: 4.4568 - val_y1_output_loss: 0.9722 - val_y2_output_loss: 3.4611 - val_y1_output_root_mean_squared_error: 0.9983 - val_y2_output_root_mean_squared_error: 1.8602
# Epoch 119/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5927 - y1_output_loss: 0.5740 - y2_output_loss: 2.0430 - y1_output_root_mean_squared_error: 0.7570 - y2_output_root_mean_squared_error: 1.4211 - val_loss: 7.9584 - val_y1_output_loss: 1.2787 - val_y2_output_loss: 6.7912 - val_y1_output_root_mean_squared_error: 1.1220 - val_y2_output_root_mean_squared_error: 2.5883
# Epoch 120/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4587 - y1_output_loss: 0.4714 - y2_output_loss: 1.9826 - y1_output_root_mean_squared_error: 0.6874 - y2_output_root_mean_squared_error: 1.4093 - val_loss: 2.5129 - val_y1_output_loss: 0.5598 - val_y2_output_loss: 1.9565 - val_y1_output_root_mean_squared_error: 0.7547 - val_y2_output_root_mean_squared_error: 1.3940
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4876 - y1_output_loss: 0.1420 - y2_output_loss: 0.3429 - y1_output_root_mean_squared_error: 0.3768 - y2_output_root_mean_squared_error: 0.5879 - val_loss: 0.7716 - val_y1_output_loss: 0.1865 - val_y2_output_loss: 0.5664 - val_y1_output_root_mean_squared_error: 0.4388 - val_y2_output_root_mean_squared_error: 0.7610
# Epoch 462/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4132 - y1_output_loss: 0.1177 - y2_output_loss: 0.2943 - y1_output_root_mean_squared_error: 0.3424 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 0.7356 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.5385 - val_y1_output_root_mean_squared_error: 0.4357 - val_y2_output_root_mean_squared_error: 0.7388
# Epoch 463/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4123 - y1_output_loss: 0.1132 - y2_output_loss: 0.2995 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.5468 - val_loss: 1.1900 - val_y1_output_loss: 0.2257 - val_y2_output_loss: 0.9777 - val_y1_output_root_mean_squared_error: 0.4780 - val_y2_output_root_mean_squared_error: 0.9806
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4618 - y1_output_loss: 0.1461 - y2_output_loss: 0.3165 - y1_output_root_mean_squared_error: 0.3830 - y2_output_root_mean_squared_error: 0.5613 - val_loss: 1.1872 - val_y1_output_loss: 0.3106 - val_y2_output_loss: 0.8891 - val_y1_output_root_mean_squared_error: 0.5562 - val_y2_output_root_mean_squared_error: 0.9369
# Epoch 465/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4732 - y1_output_loss: 0.1409 - y2_output_loss: 0.3307 - y1_output_root_mean_squared_error: 0.3745 - y2_output_root_mean_squared_error: 0.5770 - val_loss: 0.7282 - val_y1_output_loss: 0.1953 - val_y2_output_loss: 0.5303 - val_y1_output_root_mean_squared_error: 0.4403 - val_y2_output_root_mean_squared_error: 0.7310
# Epoch 466/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3659 - y1_output_loss: 0.1189 - y2_output_loss: 0.2511 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.4976 - val_loss: 2.1695 - val_y1_output_loss: 0.4440 - val_y2_output_loss: 1.6752 - val_y1_output_root_mean_squared_error: 0.6778 - val_y2_output_root_mean_squared_error: 1.3077
# Epoch 467/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.5644 - y1_output_loss: 0.1566 - y2_output_loss: 0.4086 - y1_output_root_mean_squared_error: 0.3951 - y2_output_root_mean_squared_error: 0.6390 - val_loss: 1.9814 - val_y1_output_loss: 0.6078 - val_y2_output_loss: 1.3721 - val_y1_output_root_mean_squared_error: 0.7827 - val_y2_output_root_mean_squared_error: 1.1700
# Epoch 468/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4935 - y1_output_loss: 0.1534 - y2_output_loss: 0.3370 - y1_output_root_mean_squared_error: 0.3916 - y2_output_root_mean_squared_error: 0.5832 - val_loss: 0.7882 - val_y1_output_loss: 0.1972 - val_y2_output_loss: 0.5834 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.7654
# Epoch 469/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4681 - y1_output_loss: 0.1230 - y2_output_loss: 0.3426 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.5866 - val_loss: 0.6827 - val_y1_output_loss: 0.1960 - val_y2_output_loss: 0.4797 - val_y1_output_root_mean_squared_error: 0.4486 - val_y2_output_root_mean_squared_error: 0.6939
# Epoch 470/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5152 - y1_output_loss: 0.1307 - y2_output_loss: 0.3804 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.6194 - val_loss: 0.7547 - val_y1_output_loss: 0.2195 - val_y2_output_loss: 0.5220 - val_y1_output_root_mean_squared_error: 0.4756 - val_y2_output_root_mean_squared_error: 0.7269
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4135 - y1_output_loss: 0.1189 - y2_output_loss: 0.2932 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.5424 - val_loss: 0.8237 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.6240 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.7898
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3756 - y1_output_loss: 0.1094 - y2_output_loss: 0.2634 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.5149 - val_loss: 0.7827 - val_y1_output_loss: 0.2136 - val_y2_output_loss: 0.5543 - val_y1_output_root_mean_squared_error: 0.4702 - val_y2_output_root_mean_squared_error: 0.7494
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6998 - y1_output_loss: 0.1798 - y2_output_loss: 0.5143 - y1_output_root_mean_squared_error: 0.4253 - y2_output_root_mean_squared_error: 0.7204 - val_loss: 0.7571 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.5580 - val_y1_output_root_mean_squared_error: 0.4361 - val_y2_output_root_mean_squared_error: 0.7529
# Epoch 474/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5238 - y1_output_loss: 0.1334 - y2_output_loss: 0.3862 - y1_output_root_mean_squared_error: 0.3668 - y2_output_root_mean_squared_error: 0.6239 - val_loss: 0.8136 - val_y1_output_loss: 0.2407 - val_y2_output_loss: 0.5656 - val_y1_output_root_mean_squared_error: 0.4955 - val_y2_output_root_mean_squared_error: 0.7537
# Epoch 475/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4727 - y1_output_loss: 0.1510 - y2_output_loss: 0.3193 - y1_output_root_mean_squared_error: 0.3897 - y2_output_root_mean_squared_error: 0.5665 - val_loss: 1.0604 - val_y1_output_loss: 0.2476 - val_y2_output_loss: 0.7921 - val_y1_output_root_mean_squared_error: 0.5054 - val_y2_output_root_mean_squared_error: 0.8972
# Epoch 476/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5674 - y1_output_loss: 0.1524 - y2_output_loss: 0.4125 - y1_output_root_mean_squared_error: 0.3903 - y2_output_root_mean_squared_error: 0.6443 - val_loss: 0.9283 - val_y1_output_loss: 0.2297 - val_y2_output_loss: 0.6980 - val_y1_output_root_mean_squared_error: 0.4868 - val_y2_output_root_mean_squared_error: 0.8314
# Epoch 477/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4446 - y1_output_loss: 0.1229 - y2_output_loss: 0.3318 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5700 - val_loss: 2.4963 - val_y1_output_loss: 0.8098 - val_y2_output_loss: 1.6170 - val_y1_output_root_mean_squared_error: 0.9147 - val_y2_output_root_mean_squared_error: 1.2882
# Epoch 478/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4565 - y1_output_loss: 0.1401 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.5628 - val_loss: 0.7429 - val_y1_output_loss: 0.2217 - val_y2_output_loss: 0.5179 - val_y1_output_root_mean_squared_error: 0.4786 - val_y2_output_root_mean_squared_error: 0.7168
# Epoch 479/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4943 - y1_output_loss: 0.1500 - y2_output_loss: 0.3420 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.5858 - val_loss: 0.8763 - val_y1_output_loss: 0.1840 - val_y2_output_loss: 0.6769 - val_y1_output_root_mean_squared_error: 0.4348 - val_y2_output_root_mean_squared_error: 0.8290
# Epoch 480/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3547 - y1_output_loss: 0.1292 - y2_output_loss: 0.2251 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.4754 - val_loss: 1.0536 - val_y1_output_loss: 0.3140 - val_y2_output_loss: 0.7397 - val_y1_output_root_mean_squared_error: 0.5611 - val_y2_output_root_mean_squared_error: 0.8595
# Epoch 481/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4303 - y1_output_loss: 0.1316 - y2_output_loss: 0.3005 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.5463 - val_loss: 0.9699 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.7198 - val_y1_output_root_mean_squared_error: 0.4981 - val_y2_output_root_mean_squared_error: 0.8496
# Epoch 482/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4007 - y1_output_loss: 0.1288 - y2_output_loss: 0.2806 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.5204 - val_loss: 2.4753 - val_y1_output_loss: 0.2090 - val_y2_output_loss: 2.2411 - val_y1_output_root_mean_squared_error: 0.4645 - val_y2_output_root_mean_squared_error: 1.5032
# Epoch 483/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5783 - y1_output_loss: 0.1409 - y2_output_loss: 0.4384 - y1_output_root_mean_squared_error: 0.3767 - y2_output_root_mean_squared_error: 0.6606 - val_loss: 1.7451 - val_y1_output_loss: 0.3295 - val_y2_output_loss: 1.4143 - val_y1_output_root_mean_squared_error: 0.5779 - val_y2_output_root_mean_squared_error: 1.1879
# Epoch 484/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.7106 - y1_output_loss: 0.1680 - y2_output_loss: 0.5393 - y1_output_root_mean_squared_error: 0.4087 - y2_output_root_mean_squared_error: 0.7373 - val_loss: 0.6717 - val_y1_output_loss: 0.1988 - val_y2_output_loss: 0.4776 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 0.6837
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4291 - y1_output_loss: 0.1233 - y2_output_loss: 0.3045 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5526 - val_loss: 0.8391 - val_y1_output_loss: 0.1887 - val_y2_output_loss: 0.6555 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.8044
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4112 - y1_output_loss: 0.1260 - y2_output_loss: 0.3444 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5344 - val_loss: 11.2993 - val_y1_output_loss: 0.5207 - val_y2_output_loss: 10.9657 - val_y1_output_root_mean_squared_error: 0.7258 - val_y2_output_root_mean_squared_error: 3.2821
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5212 - y1_output_loss: 0.1286 - y2_output_loss: 0.3888 - y1_output_root_mean_squared_error: 0.3599 - y2_output_root_mean_squared_error: 0.6258 - val_loss: 0.8258 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.6249 - val_y1_output_root_mean_squared_error: 0.4391 - val_y2_output_root_mean_squared_error: 0.7956
# Epoch 488/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3457 - y1_output_loss: 0.1093 - y2_output_loss: 0.2336 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4852 - val_loss: 0.8000 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.6072 - val_y1_output_root_mean_squared_error: 0.4484 - val_y2_output_root_mean_squared_error: 0.7739
# Epoch 489/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3168 - y1_output_loss: 0.1068 - y2_output_loss: 0.2110 - y1_output_root_mean_squared_error: 0.3280 - y2_output_root_mean_squared_error: 0.4574 - val_loss: 0.6470 - val_y1_output_loss: 0.1762 - val_y2_output_loss: 0.4602 - val_y1_output_root_mean_squared_error: 0.4257 - val_y2_output_root_mean_squared_error: 0.6825
# Epoch 490/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3850 - y1_output_loss: 0.1121 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.5218 - val_loss: 3.7406 - val_y1_output_loss: 0.3130 - val_y2_output_loss: 3.4664 - val_y1_output_root_mean_squared_error: 0.5657 - val_y2_output_root_mean_squared_error: 1.8495
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4968 - y1_output_loss: 0.1441 - y2_output_loss: 0.3504 - y1_output_root_mean_squared_error: 0.3790 - y2_output_root_mean_squared_error: 0.5943 - val_loss: 0.7326 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 0.4768 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.6966
# Epoch 492/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4252 - y1_output_loss: 0.1222 - y2_output_loss: 0.3061 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5504 - val_loss: 1.1031 - val_y1_output_loss: 0.2582 - val_y2_output_loss: 0.8539 - val_y1_output_root_mean_squared_error: 0.5113 - val_y2_output_root_mean_squared_error: 0.9174
# Epoch 493/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3301 - y1_output_loss: 0.1163 - y2_output_loss: 0.2120 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4620 - val_loss: 0.6358 - val_y1_output_loss: 0.1812 - val_y2_output_loss: 0.4413 - val_y1_output_root_mean_squared_error: 0.4299 - val_y2_output_root_mean_squared_error: 0.6716
# Epoch 494/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4372 - y1_output_loss: 0.1220 - y2_output_loss: 0.3238 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.5623 - val_loss: 2.2981 - val_y1_output_loss: 0.5293 - val_y2_output_loss: 1.7201 - val_y1_output_root_mean_squared_error: 0.7397 - val_y2_output_root_mean_squared_error: 1.3232
# Epoch 495/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5389 - y1_output_loss: 0.1505 - y2_output_loss: 0.3854 - y1_output_root_mean_squared_error: 0.3889 - y2_output_root_mean_squared_error: 0.6226 - val_loss: 0.9139 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 0.6539 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 0.8163
# Epoch 496/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4541 - y1_output_loss: 0.1269 - y2_output_loss: 0.3236 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.5713 - val_loss: 0.6999 - val_y1_output_loss: 0.1921 - val_y2_output_loss: 0.5015 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.7105
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4243 - y1_output_loss: 0.1162 - y2_output_loss: 0.3047 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.5542 - val_loss: 0.7979 - val_y1_output_loss: 0.2050 - val_y2_output_loss: 0.5793 - val_y1_output_root_mean_squared_error: 0.4592 - val_y2_output_root_mean_squared_error: 0.7662
# Epoch 498/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.2949 - y1_output_loss: 0.1136 - y2_output_loss: 0.1804 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4253 - val_loss: 0.8619 - val_y1_output_loss: 0.2659 - val_y2_output_loss: 0.5782 - val_y1_output_root_mean_squared_error: 0.5205 - val_y2_output_root_mean_squared_error: 0.7688
# Epoch 499/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3724 - y1_output_loss: 0.1278 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.4950 - val_loss: 0.7556 - val_y1_output_loss: 0.2178 - val_y2_output_loss: 0.5232 - val_y1_output_root_mean_squared_error: 0.4724 - val_y2_output_root_mean_squared_error: 0.7296
# Epoch 500/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3735 - y1_output_loss: 0.1192 - y2_output_loss: 0.2535 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5042 - val_loss: 0.7255 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 0.5362 - val_y1_output_root_mean_squared_error: 0.4321 - val_y2_output_root_mean_squared_error: 0.7340

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.7255 - y1_output_loss: 0.1840 - y2_output_loss: 0.5406 - y1_output_root_mean_squared_error: 0.4321 - y2_output_root_mean_squared_error: 0.7340
# Loss = 0.7255152177501034, Y1_loss = 0.18399575352668762, Y1_mse = 0.4321449100971222, Y2_loss = 0.5406327843666077, Y2_mse = 0.7340067625045776

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
